# %%
figura = [
    '''
      +---------+
      |         |
      |        _|_
      |        |__|
      |         | 
      |        /|\\
      |       / | \\
      |        / \\
      |       /   \\
      |
    ===============''',
        '''
      +---------+
      |         |
      |        _|_
      |        |__|
      |         | 
      |        /|\\
      |       / | \\
      |        /
      |       /  
      |
    ===============''',
            '''
      +---------+
      |         |
      |        _|_
      |        |__|
      |         | 
      |        /|\\
      |       / | \\
      |         |
      |          
      |
    ===============''',
            '''
      +---------+
      |         |
      |        _|_
      |        |__|
      |         | 
      |        / \\
      |       /   \\ 
      |         
      |          
      |
    ===============''',
            '''
      +---------+
      |         |
      |        _|_
      |        |__|
      |         | 
      |        /   
      |       /   
      |        
      |        
      |
    ===============''',
              '''
      +---------+
      |         |
      |        _|_
      |        |__|
      |         | 
      |          
      |          
      |        
      |        
      |
    ===============''',
              '''
      +---------+
      |         |
      |        _|_
      |        |__|
      |        
      |          
      |         
      |        
      |        
      |
    ===============''',
                '''
      +---------+
      |         |
      |         |
      |        
      |        
      |          
      |         
      |        
      |        
      |
    ===============''',
                    '''
      +
      |         
      |         
      |        
      |        
      |          
      |         
      |        
      |        
      |
    ===============''',
                        '''
      
               
               
              
              
                
               
              
              
      
    ===============''',
                            '''
      
               
               
              
              
                
               
              
              
      
    ===============''']

# %%
print(figura[0])
# Out:
#       +---------+
#       |         |
#       |        _|_
#       |        |__|
#       |         |
#       |        /|\
#       |       / | \
#       |        / \
#       |       /   \
#       |
# ...
