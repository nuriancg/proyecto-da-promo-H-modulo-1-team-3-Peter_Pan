# %%
figura = [
    '''
      +---------+
      |         |
      |        _|_
      |        |__|
      |         | 
      |        /|\\
      |       / | \\
      |        / \\
      |       /   \\
      |
    ===============''',
        '''
      +---------+
      |         |
      |        _|_
      |        |__|
      |         | 
      |        /|\\
      |       / | \\
      |        /
      |       /  
      |
    ===============''',
            '''
      +---------+
      |         |
      |        _|_
      |        |__|
      |         | 
      |        /|\\
      |       / | \\
      |         |
      |          
      |
    ===============''',
            '''
      +---------+
      |         |
      |        _|_
      |        |__|
      |         | 
      |        / \\
      |       /   \\ 
      |         
      |          
      |
    ===============''',
            '''
      +---------+
      |         |
      |        _|_
      |        |__|
      |         | 
      |        /   
      |       /   
      |        
      |        
      |
    ===============''',
              '''
      +---------+
      |         |
      |        _|_
      |        |__|
      |         | 
      |          
      |          
      |        
      |        
      |
    ===============''',
              '''
      +---------+
      |         |
      |        _|_
      |        |__|
      |        
      |          
      |         
      |        
      |        
      |
    ===============''',
                '''
      +---------+
      |         |
      |         |
      |        
      |        
      |          
      |         
      |        
      |        
      |
    ===============''',
                    '''
      +
      |         
      |         
      |        
      |        
      |          
      |         
      |        
      |        
      |
    ===============''',
                        '''
      
               
               
              
              
                
               
              
              
      
    ===============''',
                            '''
      
               
               
              
              
                
               
              
              
      
    ===============''']

# %%
print(figura[0])
# Out:
#       +---------+
#       |         |
#       |        _|_
#       |        |__|
#       |         |
#       |        /|\
#       |       / | \
#       |        / \
#       |       /   \
#       |
# ...

# %%
# Cambiado el orden para ir de 0 a 9

figura = ['''
       ===============''',
                        '''
      +
      |         
      |         
      |        
      |        
      |          
      |         
      |        
      |        
      |
    ===============''',
                    '''
      +---------+
      |         |
      |         |
      |        
      |        
      |          
      |         
      |        
      |        
      |
    ===============''',
                  '''
      +---------+
      |         |
      |        _|_
      |        |__|
      |        
      |          
      |         
      |        
      |        
      |
    ===============''',
                  '''
      +---------+
      |         |
      |        _|_
      |        |__|
      |         | 
      |          
      |          
      |        
      |        
      |
    ===============''',
                '''
      +---------+
      |         |
      |        _|_
      |        |__|
      |         | 
      |        /   
      |       /   
      |        
      |        
      |
    ===============''',
                '''
      +---------+
      |         |
      |        _|_
      |        |__|
      |         | 
      |        / \\
      |       /   \\ 
      |         
      |          
      |
    ===============''',
               '''
      +---------+
      |         |
      |        _|_
      |        |__|
      |         | 
      |        /|\\
      |       / | \\
      |         |
      |          
      |
    ===============''',
            '''
      +---------+
      |         |
      |        _|_
      |        |__|
      |         | 
      |        /|\\
      |       / | \\
      |        /
      |       /  
      |
    ===============''',
    '''
      +---------+
      |         |
      |        _|_
      |        |__|
      |         | 
      |        /|\\
      |       / | \\
      |        / \\
      |       /   \\
      |
    ==============='''
    
    
    
]

# %%
print(figura[9])
# Out:
#       +---------+
#       |         |
#       |        _|_
#       |        |__|
#       |         |
#       |        /|\
#       |       / | \
#       |        / \
#       |       /   \
#       |
# ...
